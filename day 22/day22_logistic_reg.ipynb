# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('titanic_train.csv')
df.sample(3)
# Out:
#      PassengerId  Survived  Pclass                    Name     Sex    Age  \
# 483          484         1       3  Turkula, Mrs. (Hedwig)  female  63.00
# 298          299         1       1   Saalfeld, Mr. Adolphe    male    NaN
# 644          645         1       3  Baclini, Miss. Eugenie  female   0.75
#
#      SibSp  Parch Ticket     Fare Cabin Embarked
# 483      0      0   4134   9.5875   NaN        S
# 298      0      0  19988  30.5000  C106        S
# 644      2      1   2666  19.2583   NaN        C

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# # EDa

# %%
target_cols='Survived'
cat_cols=['Pclass','Sex','Embarked']
num_cols=['Age','SibSp','Parch','Fare']
drop_cols=['PassengerId','Name','Cabin','Ticket']

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
def cat_analyze(col):
    print(col)
    print(df[col].value_counts())
    sns.countplot(data=df,x=col)
    plt.show()

for col in cat_cols:
    cat_analyze(col)
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64
# Sex
# male      577
# female    314
# Name: Sex, dtype: int64
# Embarked
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
def num_analyze(col):
    print(col)
    sns.distplot(df[col])
    plt.show()

for col in num_cols:
    num_analyze(col)
# Out:
# Age
# SibSp
# Parch
# Fare

# %%
def cat_bivariate(col):
    print(col)
    print(df.groupby(target_cols)[col].value_counts().sort_index())
    sns.countplot(data=df,x=col,hue=target_cols)
    plt.show()

for col in cat_cols:
    cat_bivariate(col)
# Out:
# Pclass
# Survived  Pclass
# 0         1          80
#           2          97
#           3         372
# 1         1         136
#           2          87
#           3         119
# Name: Pclass, dtype: int64
# Sex
# Survived  Sex
# 0         female     81
#           male      468
# 1         female    233
#           male      109
# Name: Sex, dtype: int64
# Embarked
# Survived  Embarked
# 0         C            75
#           Q            47
#           S           427
# 1         C            93
#           Q            30
#           S           217
# Name: Embarked, dtype: int64

# %%
def num_bivariate(col):
    print(col)
    plt.figure(figsize=(15,4))
    plt.subplot(1,3,1)
    sns.barplot(data=df,x=target_cols,y=col)
    plt.subplot(1,3,2)
    sns.boxplot(data=df,x=target_cols,y=col)
    plt.subplot(1,3,3)
    sns.violinplot(data=df,x=target_cols,y=col)
    plt.show()
for col in num_cols:
    num_bivariate(col)
# Out:
# Age
# SibSp
# Parch
# Fare

# %%
sns.heatmap(df[num_cols].corr(),annot=True)# annot displays value in heat map
# Out:
# <AxesSubplot:>

# %%
from random import choice

# %%
for col in cat_cols:
    if col==target_cols:
        continue
    for ncol in num_cols:
        plt.figure(figsize=(18,3))
        plt.suptitle(f'{col}vs{ncol}')
        plt.subplot(1,3,1)
        sns.boxplot(
            data=df,x=col,y=ncol,
            hue=target_cols,palette=choice(p_list)
        )
        plt.subplot(1,3,2)
        sns.violinplot(
            data=df,x=col,y=ncol,
            hue=target_cols,palette=choice(p_list)
        )
        plt.subplot(1,3,3)
        sns.barplot(
            data=df,x=col,y=ncol,
            hue=target_cols,palette=choice(p_list)
        )
        plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\DELL\Desktop\training\day 22\day22_logistic_reg.ipynb Cell 14 in <cell line: 1>()
#       <a href='vscode-notebook-cell:/c%3A/Users/DELL/Desktop/training/day%2022/day22_logistic_reg.ipynb#X22sZmlsZQ%3D%3D?line=5'>6</a> plt.suptitle(f'{col}vs{ncol}')
#       <a href='vscode-notebook-cell:/c%3A/Users/DELL/Desktop/training/day%2022/day22_logistic_reg.ipynb#X22sZmlsZQ%3D%3D?line=6'>7</a> plt.subplot(1,3,1)
#       <a href='vscode-notebook-cell:/c%3A/Users/DELL/Desktop/training/day%2022/day22_logistic_reg.ipynb#X22sZmlsZQ%3D%3D?line=7'>8</a> sns.boxplot(
#       <a href='vscode-notebook-cell:/c%3A/Users/DELL/Desktop/training/day%2022/day22_logistic_reg.ipynb#X22sZmlsZQ%3D%3D?line=8'>9</a>     data=df,x=col,y=ncol,
# ---> <a href='vscode-notebook-cell:/c%3A/Users/DELL/Desktop/training/day%2022/day22_logistic_reg.ipynb#X22sZmlsZQ%3D%3D?line=9'>10</a>     hue=target_cols,palette=choice(p_list)
#      <a href='vscode-notebook-cell:/c%3A/Users/DELL/Desktop/training/day%2022/day22_logistic_reg.ipynb#X22sZmlsZQ%3D%3D?line=10'>11</a> )
#      <a href='vscode-notebook-cell:/c%3A/Users/DELL/Desktop/training/day%2022/day22_logistic_reg.ipynb#X22sZmlsZQ%3D%3D?line=11'>12</a> plt.subplot(1,3,2)
#      <a href='vscode-notebook-cell:/c%3A/Users/DELL/Desktop/training/day%2022/day22_logistic_reg.ipynb#X22sZmlsZQ%3D%3D?line=12'>13</a> sns.violinplot(
#      <a href='vscode-notebook-cell:/c%3A/Users/DELL/Desktop/training/day%2022/day22_logistic_reg.ipynb#X22sZmlsZQ%3D%3D?line=13'>14</a>     data=df,x=col,y=ncol,
#      <a href='vscode-notebook-cell:/c%3A/Users/DELL/Desktop/training/day%2022/day22_logistic_reg.ipynb#X22sZmlsZQ%3D%3D?line=14'>15</a>     hue=target_cols,palette=choice(p_list)
#      <a href='vscode-notebook-cell:/c%3A/Users/DELL/Desktop/training/day%2022/day22_logistic_reg.ipynb#X22sZmlsZQ%3D%3D?line=15'>16</a> )
#
# NameError: name 'p_list' is not defined

# %%
df.drop(drop_cols,axis=1,inplace=True)

# %%
# Missing data identification
pd.isnull(df)
# Out:
#      Survived  Pclass    Sex    Age  SibSp  Parch   Fare  Embarked
# 0       False   False  False  False  False  False  False     False
# 1       False   False  False  False  False  False  False     False
# 2       False   False  False  False  False  False  False     False
# 3       False   False  False  False  False  False  False     False
# 4       False   False  False  False  False  False  False     False
# ..        ...     ...    ...    ...    ...    ...    ...       ...
# 886     False   False  False  False  False  False  False     False
# 887     False   False  False  False  False  False  False     False
# 888     False   False  False   True  False  False  False     False
# 889     False   False  False  False  False  False  False     False
# 890     False   False  False  False  False  False  False     False
#
# [891 rows x 8 columns]

# %%
pd.isnull(df).sum()
# Out:
# Survived      0
# Pclass        0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Fare          0
# Embarked      2
# dtype: int64

# %%
100*pd.isnull(df).sum()/len(df)
# Out:
# Survived     0.000000
# Pclass       0.000000
# Sex          0.000000
# Age         19.865320
# SibSp        0.000000
# Parch        0.000000
# Fare         0.000000
# Embarked     0.224467
# dtype: float64

# %%
plt.figure(figsize=(18,5))
sns.heatmap(pd.isnull(df))
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(18,5))
sns.heatmap(pd.isnull(df))
# Out:
# <AxesSubplot:>

# %%
sns.set_style('whitegrid')

# %%
sns.barplot(data=df,x='Survived',y='Age')
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='Age'>

# %%
df.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df['Age'].mean()
# Out:
# 29.69911764705882

# %%
df['Age'].fillna(df['Age'].mean()).mean()
# Out:
# 29.699117647058763

# %%
sns.barplot(data=df,y='Age',x='Pclass',hue='Sex')
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Age'>

# %%
df.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0         0       3    male  22.0      1      0   7.2500        S
# 1         1       1  female  38.0      1      0  71.2833        C
# 2         1       3  female  26.0      0      0   7.9250        S
# 3         1       1  female  35.0      1      0  53.1000        S
# 4         0       3    male  35.0      0      0   8.0500        S

# %%
# Impute the fake entries in missing Age Information
def age_imputer(data):
    age=data['Age']
    pclass=data['Pclass']
    sex=data['Sex']
    if pd.isnull(age):
        return df['Age'][(df['Pclass']==pclass)&(df['Sex']==sex)].mean()
    else:
        return age

df['Age']=df.apply(age_imputer,axis=1)

# %%
plt.figure(figsize=(18,10))
sns.heatmap(pd.isnull(df))
# Out:
# <AxesSubplot:>

# %%
#Dropping missing entries which were very less (in Embarked Column)
df.dropna(inplace=True)

# %%
plt.figure(figsize=(8,5))
sns.heatmap(pd.isnull(df))
# Out:
# <AxesSubplot:>

# %%
100*pd.isnull(df).sum()/len(df)
# Out:
# Survived    0.0
# Pclass      0.0
# Sex         0.0
# Age         0.0
# SibSp       0.0
# Parch       0.0
# Fare        0.0
# Embarked    0.0
# dtype: float64

# %%
pd.get_dummies(df)
# Out:
#      Survived  Pclass    Age  SibSp  Parch     Fare  Sex_female  Sex_male  \
# 0           0       3  22.00      1      0   7.2500           0         1
# 1           1       1  38.00      1      0  71.2833           1         0
# 2           1       3  26.00      0      0   7.9250           1         0
# 3           1       1  35.00      1      0  53.1000           1         0
# 4           0       3  35.00      0      0   8.0500           0         1
# ..        ...     ...    ...    ...    ...      ...         ...       ...
# 886         0       2  27.00      0      0  13.0000           0         1
# 887         1       1  19.00      0      0  30.0000           1         0
# 888         0       3  21.75      1      2  23.4500           1         0
# 889         1       1  26.00      0      0  30.0000           0         1
# 890         0       3  32.00      0      0   7.7500           0         1
#
#      Embarked_C  Embarked_Q  Embarked_S
# 0             0           0           1
# 1             1           0           0
# 2             0           0           1
# 3             0           0           1
# 4             0           0           1
# ..          ...         ...         ...
# 886           0           0           1
# 887           0           0           1
# 888           0           0           1
# 889           1           0           0
# 890           0           1           0
#
# [889 rows x 11 columns]

# %%
data=pd.get_dummies(df).drop('Sex_female',axis=1)

# %%
data.head()
# Out:
#    Survived  Pclass   Age  SibSp  Parch     Fare  Sex_male  Embarked_C  \
# 0         0       3  22.0      1      0   7.2500         1           0
# 1         1       1  38.0      1      0  71.2833         0           1
# 2         1       3  26.0      0      0   7.9250         0           0
# 3         1       1  35.0      1      0  53.1000         0           0
# 4         0       3  35.0      0      0   8.0500         1           0
#
#    Embarked_Q  Embarked_S
# 0           0           1
# 1           0           0
# 2           0           1
# 3           0           1
# 4           0           1

# %%
sns.pairplot(data)

# %%
target=data[target_cols]
features=data.drop(target_cols,axis=1)

# %%
target.head()
# Out:
# 0    0
# 1    1
# 2    1
# 3    1
# 4    0
# Name: Survived, dtype: int64

# %%
features.head()
# Out:
#    Pclass   Age  SibSp  Parch     Fare  Sex_male  Embarked_C  Embarked_Q  \
# 0       3  22.0      1      0   7.2500         1           0           0
# 1       1  38.0      1      0  71.2833         0           1           0
# 2       3  26.0      0      0   7.9250         0           0           0
# 3       1  35.0      1      0  53.1000         0           0           0
# 4       3  35.0      0      0   8.0500         1           0           0
#
#    Embarked_S
# 0           1
# 1           0
# 2           1
# 3           1
# 4           1

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(features,target,test_size=0.25,random_state=101)

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()
model.fit(xtrain,ytrain)
# Out:
# LogisticRegression()

# %%
print(round(100*model.score(xtest,ytest)),'%')
# Out:
# 83 %

# %%
# Confusion Matrix and Classification Report
from sklearn.metrics import confusion_matrix,classification_report
ytest_pred=model.predict(xtest)
sns.heatmap(confusion_matrix(ytest,ytest_pred),annot=True,fmt='d')
plt.show()
print(classification_report(ytest,ytest_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.93      0.87       136
#            1       0.86      0.69      0.76        87
#
#     accuracy                           0.83       223
#    macro avg       0.84      0.81      0.82       223
# weighted avg       0.84      0.83      0.83       223

# %%
# Putting Class Weights/Hyperparam
model1=LogisticRegression(class_weight={0:0.9,1:0.6},random_state=101)
model1.fit(xtrain,ytrain)
print(classification_report(ytest,model1.predict(xtest)))

# This method did not work
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.96      0.87       136
#            1       0.90      0.62      0.73        87
#
#     accuracy                           0.83       223
#    macro avg       0.85      0.79      0.80       223
# weighted avg       0.84      0.83      0.82       223

# %%
# Hyperparam
for algo in ['newton-cg','lbfgs','liblinear','sag','saga']:
    print(algo)
    model_algo=LogisticRegression(random_state=101,solver=algo,tol=1,C=1)
    model_algo.fit(xtrain,ytrain)
    print(classification_report(ytest,model_algo.predict(xtest)))
# Out:
# newton-cg
#               precision    recall  f1-score   support
#
#            0       0.82      0.93      0.87       136
#            1       0.86      0.69      0.76        87
#
#     accuracy                           0.83       223
#    macro avg       0.84      0.81      0.82       223
# weighted avg       0.84      0.83      0.83       223
#
# lbfgs
#               precision    recall  f1-score   support
#
#            0       0.82      0.93      0.87       136
#            1       0.86      0.69      0.76        87
#
#     accuracy                           0.83       223
#    macro avg       0.84      0.81      0.82       223
# weighted avg       0.84      0.83      0.83       223
#
# liblinear
#               precision    recall  f1-score   support
#
#            0       0.69      0.93      0.79       136
#            1       0.75      0.34      0.47        87
#
#     accuracy                           0.70       223
#    macro avg       0.72      0.64      0.63       223
# weighted avg       0.71      0.70      0.67       223
#
# sag
#               precision    recall  f1-score   support
#
#            0       0.67      0.93      0.78       136
#            1       0.73      0.28      0.40        87
#
#     accuracy                           0.68       223
#    macro avg       0.70      0.60      0.59       223
# weighted avg       0.69      0.68      0.63       223
#
# saga
#               precision    recall  f1-score   support
#
#            0       0.68      0.93      0.79       136
#            1       0.76      0.32      0.45        87
#
#     accuracy                           0.70       223
#    macro avg       0.72      0.63      0.62       223
# weighted avg       0.71      0.70      0.66       223

# %%
# This model is not really improving so we should not consider it as the score was low as compared to
# criticalness of the situation

# %%
xtrain,xtest,ytrain,ytest
# Out:
# (     Pclass        Age  SibSp  Parch     Fare  Sex_male  Embarked_C  \
#  127       3  24.000000      0      0   7.1417         1           0
#  133       2  29.000000      1      0  26.0000         0           0
#  619       2  26.000000      0      0  10.5000         1           0
#  439       2  31.000000      0      0  10.5000         1           0
#  374       3   3.000000      3      1  21.0750         0           0
#  ..      ...        ...    ...    ...      ...       ...         ...
#  576       2  34.000000      0      0  13.0000         0           0
#  840       3  20.000000      0      0   7.9250         1           0
#  338       3  45.000000      0      0   8.0500         1           0
#  524       3  26.507589      0      0   7.2292         1           1
#  865       2  42.000000      0      0  13.0000         0           0
#
#       Embarked_Q  Embarked_S
#  127           0           1
#  133           0           1
#  619           0           1
#  439           0           1
#  374           0           1
#  ..          ...         ...
#  576           0           1
#  840           0           1
#  338           0           1
#  524           0           0
#  865           0           1
#
#  [666 rows x 9 columns],
#       Pclass        Age  SibSp  Parch      Fare  Sex_male  Embarked_C  \
#  511       3  26.507589      0      0    8.0500         1           0
#  613       3  26.507589      0      0    7.7500         1           0
#  615       2  24.000000      1      2   65.0000         0           0
#  337       1  41.000000      0      0  134.5000         0           1
#  718       3  26.507589      0      0   15.5000         1           0
#  ..      ...        ...    ...    ...       ...       ...         ...
#  731       3  11.000000      0      0   18.7875         1           1
#  630       1  80.000000      0      0   30.0000         1           0
#  184       3   4.000000      0      2   22.0250         0           0
#  422       3  29.000000      0      0    7.8750         1           0
#  181       2  30.740707      0      0   15.0500         1           1
#
#       Embarked_Q  Embarked_S
#  511           0           1
#  613           1           0
#  615           0           1
#  337           0           0
#  718           1           0
#  ..          ...         ...
#  731           0           0
#  630           0           1
#  184           0           1
#  422           0           1
#  181           0           0
#
#  [223 rows x 9 columns],
#  127    1
#  133    1
#  619    0
#  439    0
#  374    0
#        ..
#  576    1
#  840    0
#  338    1
#  524    0
#  865    1
#  Name: Survived, Length: 666, dtype: int64,
#  511    0
#  613    0
#  615    1
#  337    1
#  718    0
#        ..
#  731    0
#  630    1
#  184    1
#  422    0
#  181    0
#  Name: Survived, Length: 223, dtype: int64)

# %%
from sklearn.tree import DecisionTreeClassifier

model_dt=DecisionTreeClassifier().fit(xtrain,ytrain)
print(classification_report(ytest,model_dt.predict(xtest)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.79      0.80       136
#            1       0.68      0.71      0.70        87
#
#     accuracy                           0.76       223
#    macro avg       0.75      0.75      0.75       223
# weighted avg       0.76      0.76      0.76       223

# %%
# Gini Index-----Continuous
#Information Index---Categorical

# %%
pd.DataFrame(model_dt.feature_importances_,index=xtrain.columns,columns=['Importance']).sort_values(by='Importance',ascending=False)
# Out:
#             Importance
# Sex_male      0.298897
# Fare          0.247149
# Age           0.245446
# Pclass        0.097757
# SibSp         0.059332
# Parch         0.028516
# Embarked_C    0.015279
# Embarked_S    0.007624
# Embarked_Q    0.000000

# %%
imp_cols=['Sex_male','Fare','Age']

# %%
model_dt2=DecisionTreeClassifier().fit(xtrain[imp_cols],ytrain)
print(classification_report(ytest,model_dt2.predict(xtest[imp_cols])))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.75      0.77       136
#            1       0.64      0.70      0.67        87
#
#     accuracy                           0.73       223
#    macro avg       0.72      0.73      0.72       223
# weighted avg       0.74      0.73      0.73       223

# %%
pd.DataFrame(model_rf.feature_importances_,index=xtrain.columns,columns=['Importance']).sort_values(by='Importance',ascending=False)
# Out:
#             Importance
# Fare          0.277890
# Age           0.271630
# Sex_male      0.241868
# Pclass        0.080650
# SibSp         0.048425
# Parch         0.038369
# Embarked_S    0.019354
# Embarked_C    0.013849
# Embarked_Q    0.007963

# %%
model_rf2=RandomForestClassifier().fit(xtrain[imp_cols],ytrain)
print(classification_report(ytest,model_rf2.predict(xtest[imp_cols])))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.86      0.83       136
#            1       0.75      0.67      0.71        87
#
#     accuracy                           0.78       223
#    macro avg       0.78      0.76      0.77       223
# weighted avg       0.78      0.78      0.78       223

# %%
pd.to_pickle(model_rf2,'SurvivalPredictionRF.pickle')
pd.to_pickle(model,'SurvivalPredictionLogisticR.pickle')
